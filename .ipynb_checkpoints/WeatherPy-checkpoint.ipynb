# %% [markdown]
# # WeatherPy
#
# ---
#
# ## Starter Code to Generate Random Geographic Coordinates and a List of Cities

# %%
# Dependencies and Setup
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
import requests
import time
from scipy.stats import linregress

# Impor the OpenWeatherMap API key
from api_keys import weather_api_key

# Import citipy to determine the cities based on latitude and longitude
from citipy import citipy

# %% [markdown]
# ### Generate the Cities List by Using the `citipy` Library

# %%
# Empty list for holding the latitude and longitude combinations
lat_lngs = []

# Empty list for holding the cities names
cities = []

# Range of latitudes and longitudes
lat_range = (-90, 90)
lng_range = (-180, 180)

# Create a set of random lat and lng combinations
lats = np.random.uniform(lat_range[0], lat_range[1], size=1500)
lngs = np.random.uniform(lng_range[0], lng_range[1], size=1500)
lat_lngs = zip(lats, lngs)

# Identify nearest city for each lat, lng combination
for lat_lng in lat_lngs:
    city = citipy.nearest_city(lat_lng[0], lat_lng[1]).city_name

    # If the city is unique, then add it to a our cities list
    if city not in cities:
        cities.append(city)

# Print the city count to confirm sufficient count
print(f"Number of cities in the list: {len(cities)}")
# Out:
# Number of cities in the list: 606

# %% [markdown]
# ---

# %% [markdown]
# ## Requirement 1: Create Plots to Showcase the Relationship Between Weather Variables and Latitude
#
# ### Use the OpenWeatherMap API to retrieve weather data from the cities list generated in the started code

# %%
# Set the API base URL
url = f"http://api.openweathermap.org/data/2.5/weather?units=Imperial&appid={weather_api_key}"

# Define an empty list to fetch the weather data for each city
city_data = []

# Print to logger
print("Beginning Data Retrieval     ")
print("-----------------------------")

# Create counters
record_count = 1
set_count = 1

# Loop through all the cities in our list to fetch weather data
for i, city in enumerate(cities):

    # Group cities in sets of 50 for logging purposes
    if (i % 50 == 0 and i >= 50):
        set_count += 1
        record_count = 0

    # Create endpoint URL with each city
    city_url = f"{url}&q={city}"

    # Log the url, record, and set numbers
    print("Processing Record %s of Set %s | %s" % (record_count, set_count, city))

    # Add 1 to the record count
    record_count += 1

    # Run an API request for each of the cities
    try:
        # Parse the JSON and retrieve data
        city_weather = requests.get(city_url).json()

        # pause for 1 second using time.sleep() - avoids the OpenWeather API key from being disabled
        time.sleep(1)

        # Parse out latitude, longitude, max temp, humidity, cloudiness, wind speed, country, and date
        city_lat = city_weather['coord']['lat']
        city_lng = city_weather['coord']['lon']
        city_max_temp = city_weather['main']['temp_max']
        city_humidity = city_weather['main']['humidity']
        city_clouds = city_weather['clouds']['all']
        city_wind = city_weather['wind']['speed']
        city_country = city_weather['sys']['country']
        city_date = city_weather['dt']

        # Append the City information into city_data list
        city_data.append({"City": city,
                          "Lat": city_lat,
                          "Lng": city_lng,
                          "Max Temp": city_max_temp,
                          "Humidity": city_humidity,
                          "Cloudiness": city_clouds,
                          "Wind Speed": city_wind,
                          "Country": city_country,
                          "Date": city_date})

    # If an error is experienced, skip the city
    except:
        print("City not found. Skipping...")
        pass

# Indicate that Data Loading is complete
print("-----------------------------")
print("Data Retrieval Complete      ")
print("-----------------------------")
# Out:
# Beginning Data Retrieval
# -----------------------------
# Processing Record 1 of Set 1 | constantia
# Processing Record 2 of Set 1 | kodiak
# Processing Record 3 of Set 1 | dadonghai
# City not found. Skipping...
# Processing Record 4 of Set 1 | waitangi
# Processing Record 5 of Set 1 | khandyga
# Processing Record 6 of Set 1 | saipan
# Processing Record 7 of Set 1 | punta arenas
# Processing Record 8 of Set 1 | veinticinco de mayo
# Processing Record 9 of Set 1 | yellowknife
# Processing Record 10 of Set 1 | port-aux-francais
# Processing Record 11 of Set 1 | flying fish cove
# Processing Record 12 of Set 1 | ulsteinvik
# Processing Record 13 of Set 1 | vorgashor
# Processing Record 14 of Set 1 | stanley
# Processing Record 15 of Set 1 | ravenna
# Processing Record 16 of Set 1 | port mathurin
# Processing Record 17 of Set 1 | edinburgh of the seven seas
# Processing Record 18 of Set 1 | hamilton
# Processing Record 19 of Set 1 | hermanus
# Processing Record 20 of Set 1 | vipiteno
# Processing Record 21 of Set 1 | las choapas
# Processing Record 22 of Set 1 | adamstown
# Processing Record 23 of Set 1 | mana
# Processing Record 24 of Set 1 | muynoq
# Processing Record 25 of Set 1 | leava
# Processing Record 26 of Set 1 | albany
# Processing Record 27 of Set 1 | barra do corda
# Processing Record 28 of Set 1 | terrace
# Processing Record 29 of Set 1 | fale old settlement
# Processing Record 30 of Set 1 | bethel
# Processing Record 31 of Set 1 | margaret river
# Processing Record 32 of Set 1 | grand falls-windsor
# Processing Record 33 of Set 1 | dunedin
# Processing Record 34 of Set 1 | benoy-yurt
# Processing Record 35 of Set 1 | tiksi
# Processing Record 36 of Set 1 | ust-nera
# Processing Record 37 of Set 1 | sola
# Processing Record 38 of Set 1 | ushuaia
# Processing Record 39 of Set 1 | gounou gaya
# Processing Record 40 of Set 1 | vinh
# Processing Record 41 of Set 1 | fada
# Processing Record 42 of Set 1 | aitape
# Processing Record 43 of Set 1 | port elizabeth
# Processing Record 44 of Set 1 | krasnoslobodsk
# Processing Record 45 of Set 1 | kuala tungkal
# Processing Record 46 of Set 1 | kairouan
# Processing Record 47 of Set 1 | al ghayzah
# Processing Record 48 of Set 1 | wailua homesteads
# Processing Record 49 of Set 1 | tura
# Processing Record 50 of Set 1 | petropavlovsk-kamchatsky
# Processing Record 0 of Set 2 | port alfred
# Processing Record 1 of Set 2 | katagum
# Processing Record 2 of Set 2 | puerto ayora
# Processing Record 3 of Set 2 | dalandzadgad
# Processing Record 4 of Set 2 | bredasdorp
# Processing Record 5 of Set 2 | blackmans bay
# Processing Record 6 of Set 2 | iskateley
# Processing Record 7 of Set 2 | turkmenbasy
# Processing Record 8 of Set 2 | hawaiian paradise park
# Processing Record 9 of Set 2 | erenhot
# Processing Record 10 of Set 2 | papatowai
# Processing Record 11 of Set 2 | belyy yar
# Processing Record 12 of Set 2 | ilulissat
# Processing Record 13 of Set 2 | zinjibar
# Processing Record 14 of Set 2 | priyutnoye
# Processing Record 15 of Set 2 | manggar
# Processing Record 16 of Set 2 | guerrero negro
# Processing Record 17 of Set 2 | tranovaho
# City not found. Skipping...
# Processing Record 18 of Set 2 | grytviken
# Processing Record 19 of Set 2 | vesoul
# Processing Record 20 of Set 2 | saint-pierre
# Processing Record 21 of Set 2 | colonia
# Processing Record 22 of Set 2 | zhangye
# Processing Record 23 of Set 2 | tangalle
# Processing Record 24 of Set 2 | puerto natales
# Processing Record 25 of Set 2 | elmendorf air force base
# City not found. Skipping...
# Processing Record 26 of Set 2 | kupang
# Processing Record 27 of Set 2 | las tablas
# Processing Record 28 of Set 2 | svetlyy
# Processing Record 29 of Set 2 | puerto san jose
# Processing Record 30 of Set 2 | lorengau
# Processing Record 31 of Set 2 | avarua
# Processing Record 32 of Set 2 | yuzhno-kurilsk
# Processing Record 33 of Set 2 | polyarnyy
# Processing Record 34 of Set 2 | atafu village
# Processing Record 35 of Set 2 | port-vila
# Processing Record 36 of Set 2 | invercargill
# Processing Record 37 of Set 2 | kavaratti
# Processing Record 38 of Set 2 | al jahra'
# Processing Record 39 of Set 2 | portland
# Processing Record 40 of Set 2 | olonkinbyen
# Processing Record 41 of Set 2 | lesogorsk
# Processing Record 42 of Set 2 | lihue
# Processing Record 43 of Set 2 | awjilah
# Processing Record 44 of Set 2 | krasnozerskoye
# Processing Record 45 of Set 2 | ghormach
# Processing Record 46 of Set 2 | camana
# Processing Record 47 of Set 2 | aasiaat
# Processing Record 48 of Set 2 | susuman
# Processing Record 49 of Set 2 | gerash
# Processing Record 0 of Set 3 | el-tor
# Processing Record 1 of Set 3 | iqaluit
# Processing Record 2 of Set 3 | puerto colombia
# Processing Record 3 of Set 3 | taoudenni
# Processing Record 4 of Set 3 | nuuk
# Processing Record 5 of Set 3 | ribeira grande
# Processing Record 6 of Set 3 | taiohae
# City not found. Skipping...
# Processing Record 7 of Set 3 | nishinoomote
# Processing Record 8 of Set 3 | isafjordur
# Processing Record 9 of Set 3 | muzayri'
# City not found. Skipping...
# Processing Record 10 of Set 3 | afaahiti
# Processing Record 11 of Set 3 | coquimbo
# Processing Record 12 of Set 3 | porto novo
# Processing Record 13 of Set 3 | bilibino
# Processing Record 14 of Set 3 | ancud
# Processing Record 15 of Set 3 | tolanaro
# Processing Record 16 of Set 3 | juan griego
# Processing Record 17 of Set 3 | enewetak
# Processing Record 18 of Set 3 | saint-francois
# Processing Record 19 of Set 3 | halifax
# Processing Record 20 of Set 3 | longyearbyen
# Processing Record 21 of Set 3 | lebu
# Processing Record 22 of Set 3 | dire
# Processing Record 23 of Set 3 | la rinconada
# Processing Record 24 of Set 3 | irymple
# Processing Record 25 of Set 3 | anadyr
# Processing Record 26 of Set 3 | la sarre
# Processing Record 27 of Set 3 | klyuchi
# Processing Record 28 of Set 3 | ataq
# Processing Record 29 of Set 3 | bubaque
# Processing Record 30 of Set 3 | ulanhot
# Processing Record 31 of Set 3 | okha
# Processing Record 32 of Set 3 | mount isa
# Processing Record 33 of Set 3 | tokar
# Processing Record 34 of Set 3 | luau
# Processing Record 35 of Set 3 | urumqi
# Processing Record 36 of Set 3 | oualidia
# City not found. Skipping...
# Processing Record 37 of Set 3 | dompu
# Processing Record 38 of Set 3 | saldanha
# Processing Record 39 of Set 3 | cabedelo
# Processing Record 40 of Set 3 | hasaki
# Processing Record 41 of Set 3 | sinan
# Processing Record 42 of Set 3 | talnakh
# Processing Record 43 of Set 3 | cesky krumlov
# Processing Record 44 of Set 3 | murghob
# Processing Record 45 of Set 3 | kuala belait
# Processing Record 46 of Set 3 | kamloops
# Processing Record 47 of Set 3 | brokopondo
# Processing Record 48 of Set 3 | kruisfontein
# Processing Record 49 of Set 3 | peace river
# Processing Record 0 of Set 4 | oyama
# Processing Record 1 of Set 4 | winona
# Processing Record 2 of Set 4 | mejit
# Processing Record 3 of Set 4 | uturoa
# Processing Record 4 of Set 4 | satupa'itea
# City not found. Skipping...
# Processing Record 5 of Set 4 | cabo san lucas
# Processing Record 6 of Set 4 | falkenberg
# Processing Record 7 of Set 4 | chonchi
# Processing Record 8 of Set 4 | kingston
# Processing Record 9 of Set 4 | jamestown
# Processing Record 10 of Set 4 | yarmouth
# Processing Record 11 of Set 4 | uige
# Processing Record 12 of Set 4 | touros
# Processing Record 13 of Set 4 | mil'kovo
# Processing Record 14 of Set 4 | badger
# Processing Record 15 of Set 4 | borogontsy
# Processing Record 16 of Set 4 | tanrake village
# City not found. Skipping...
# Processing Record 17 of Set 4 | big stone gap
# Processing Record 18 of Set 4 | isla mujeres
# Processing Record 19 of Set 4 | sheridan
# Processing Record 20 of Set 4 | farim
# Processing Record 21 of Set 4 | georgetown
# Processing Record 22 of Set 4 | bundaberg north
# Processing Record 23 of Set 4 | as sulayyil
# Processing Record 24 of Set 4 | crane
# Processing Record 25 of Set 4 | palikir - national government center
# Processing Record 26 of Set 4 | pangody
# Processing Record 27 of Set 4 | taltal
# Processing Record 28 of Set 4 | utrik
# Processing Record 29 of Set 4 | kidal
# Processing Record 30 of Set 4 | qaqortoq
# Processing Record 31 of Set 4 | akhmet'a
# Processing Record 32 of Set 4 | timimoun
# Processing Record 33 of Set 4 | salinopolis
# Processing Record 34 of Set 4 | martins ferry
# Processing Record 35 of Set 4 | kafir qala
# Processing Record 36 of Set 4 | minas de marcona
# Processing Record 37 of Set 4 | mournies
# Processing Record 38 of Set 4 | lethem
# Processing Record 39 of Set 4 | kita
# Processing Record 40 of Set 4 | lompoc
# Processing Record 41 of Set 4 | kamaishi
# Processing Record 42 of Set 4 | nabire
# Processing Record 43 of Set 4 | vernon
# Processing Record 44 of Set 4 | northam
# Processing Record 45 of Set 4 | arraial do cabo
# Processing Record 46 of Set 4 | serdar
# Processing Record 47 of Set 4 | khorol
# Processing Record 48 of Set 4 | kuqa
# Processing Record 49 of Set 4 | baker city
# Processing Record 0 of Set 5 | saudarkrokur
# Processing Record 1 of Set 5 | port lincoln
# Processing Record 2 of Set 5 | keflavik
# Processing Record 3 of Set 5 | villanueva
# Processing Record 4 of Set 5 | sydney mines
# Processing Record 5 of Set 5 | verkhnevilyuysk
# Processing Record 6 of Set 5 | motygino
# Processing Record 7 of Set 5 | remire-montjoly
# Processing Record 8 of Set 5 | homer
# Processing Record 9 of Set 5 | villa dolores
# Processing Record 10 of Set 5 | dudinka
# Processing Record 11 of Set 5 | thompson
# Processing Record 12 of Set 5 | bayside
# Processing Record 13 of Set 5 | varna
# Processing Record 14 of Set 5 | iyidere
# Processing Record 15 of Set 5 | praia da vitoria
# Processing Record 16 of Set 5 | boundiali
# Processing Record 17 of Set 5 | aljezur
# Processing Record 18 of Set 5 | alice springs
# Processing Record 19 of Set 5 | college
# Processing Record 20 of Set 5 | hithadhoo
# Processing Record 21 of Set 5 | nova sintra
# Processing Record 22 of Set 5 | turpan
# Processing Record 23 of Set 5 | ziway
# Processing Record 24 of Set 5 | san patricio
# Processing Record 25 of Set 5 | amarillo
# Processing Record 26 of Set 5 | santo domingo zanatepec
# Processing Record 27 of Set 5 | sakata
# Processing Record 28 of Set 5 | ayvacik
# Processing Record 29 of Set 5 | fuvahmulah
# City not found. Skipping...
# Processing Record 30 of Set 5 | brookings
# Processing Record 31 of Set 5 | celestun
# Processing Record 32 of Set 5 | basco
# Processing Record 33 of Set 5 | uliastay
# Processing Record 34 of Set 5 | la passe
# Processing Record 35 of Set 5 | west island
# Processing Record 36 of Set 5 | embi
# Processing Record 37 of Set 5 | shingu
# Processing Record 38 of Set 5 | beato antonio
# Processing Record 39 of Set 5 | sovetskaya gavan'
# Processing Record 40 of Set 5 | kalmunai
# Processing Record 41 of Set 5 | camlachie
# Processing Record 42 of Set 5 | zeya
# Processing Record 43 of Set 5 | baidoa
# Processing Record 44 of Set 5 | bardai
# Processing Record 45 of Set 5 | mahebourg
# Processing Record 46 of Set 5 | plastun
# Processing Record 47 of Set 5 | namibe
# Processing Record 48 of Set 5 | hayma'
# City not found. Skipping...
# Processing Record 49 of Set 5 | newman
# Processing Record 0 of Set 6 | fisterra
# Processing Record 1 of Set 6 | vingt cinq
# City not found. Skipping...
# Processing Record 2 of Set 6 | fuerte olimpo
# Processing Record 3 of Set 6 | christchurch
# Processing Record 4 of Set 6 | arthur's town
# City not found. Skipping...
# Processing Record 5 of Set 6 | juneau
# Processing Record 6 of Set 6 | palmer
# Processing Record 7 of Set 6 | brisas de zicatela
# Processing Record 8 of Set 6 | boguchany
# Processing Record 9 of Set 6 | haparanda
# Processing Record 10 of Set 6 | new norfolk
# Processing Record 11 of Set 6 | hadibu
# Processing Record 12 of Set 6 | urangan
# Processing Record 13 of Set 6 | zav'yalovo
# Processing Record 14 of Set 6 | jamnagar
# Processing Record 15 of Set 6 | whitehorse
# Processing Record 16 of Set 6 | prince albert
# Processing Record 17 of Set 6 | loch garman
# Processing Record 18 of Set 6 | vila franca do campo
# Processing Record 19 of Set 6 | hualien city
# Processing Record 20 of Set 6 | yanam
# Processing Record 21 of Set 6 | lubao
# Processing Record 22 of Set 6 | jining
# Processing Record 23 of Set 6 | tazovsky
# Processing Record 24 of Set 6 | bismarck
# Processing Record 25 of Set 6 | greymouth
# Processing Record 26 of Set 6 | at taj
# Processing Record 27 of Set 6 | harper
# Processing Record 28 of Set 6 | mukah
# City not found. Skipping...
# Processing Record 29 of Set 6 | dubbo
# Processing Record 30 of Set 6 | balykshi
# Processing Record 31 of Set 6 | egilsstadir
# Processing Record 32 of Set 6 | kailua-kona
# Processing Record 33 of Set 6 | mogocha
# Processing Record 34 of Set 6 | calca
# Processing Record 35 of Set 6 | el calafate
# Processing Record 36 of Set 6 | dryden
# Processing Record 37 of Set 6 | gadzhiyevo
# Processing Record 38 of Set 6 | mount pearl
# Processing Record 39 of Set 6 | raciborz
# Processing Record 40 of Set 6 | tame
# Processing Record 41 of Set 6 | ta`u
# Processing Record 42 of Set 6 | sitka
# Processing Record 43 of Set 6 | atlantic beach
# Processing Record 44 of Set 6 | mizdah
# Processing Record 45 of Set 6 | kristiansund
# Processing Record 46 of Set 6 | sonsorol village
# City not found. Skipping...
# Processing Record 47 of Set 6 | susanville
# Processing Record 48 of Set 6 | novodvinsk
# Processing Record 49 of Set 6 | flin flon
# Processing Record 0 of Set 7 | el porvenir
# Processing Record 1 of Set 7 | carnarvon
# Processing Record 2 of Set 7 | greater sudbury
# Processing Record 3 of Set 7 | mili
# Processing Record 4 of Set 7 | nova vicosa
# Processing Record 5 of Set 7 | fort st. john
# Processing Record 6 of Set 7 | rongelap
# Processing Record 7 of Set 7 | alofi
# Processing Record 8 of Set 7 | ouro preto do oeste
# Processing Record 9 of Set 7 | dordrecht
# Processing Record 10 of Set 7 | port douglas
# Processing Record 11 of Set 7 | queenstown
# Processing Record 12 of Set 7 | la jolla
# Processing Record 13 of Set 7 | paracuru
# Processing Record 14 of Set 7 | arkhangel'sk
# Processing Record 15 of Set 7 | tofol
# Processing Record 16 of Set 7 | rey bouba
# Processing Record 17 of Set 7 | seoni malwa
# Processing Record 18 of Set 7 | yelabuga
# Processing Record 19 of Set 7 | nova xavantina
# Processing Record 20 of Set 7 | westport
# Processing Record 21 of Set 7 | laayoune
# Processing Record 22 of Set 7 | sabha
# Processing Record 23 of Set 7 | sao felix do xingu
# Processing Record 24 of Set 7 | nichinan
# Processing Record 25 of Set 7 | nchelenge
# Processing Record 26 of Set 7 | ola
# Processing Record 27 of Set 7 | pyhajarvi
# Processing Record 28 of Set 7 | hoxtolgay
# City not found. Skipping...
# Processing Record 29 of Set 7 | motueka
# Processing Record 30 of Set 7 | tsiombe
# Processing Record 31 of Set 7 | balnearia
# Processing Record 32 of Set 7 | mancio lima
# Processing Record 33 of Set 7 | anabar
# City not found. Skipping...
# Processing Record 34 of Set 7 | sisimiut
# Processing Record 35 of Set 7 | ha tinh
# Processing Record 36 of Set 7 | macas
# Processing Record 37 of Set 7 | ar rahad
# Processing Record 38 of Set 7 | kununurra
# Processing Record 39 of Set 7 | nguigmi
# Processing Record 40 of Set 7 | aykhal
# Processing Record 41 of Set 7 | hobyo
# Processing Record 42 of Set 7 | devarkonda
# Processing Record 43 of Set 7 | starominskaya
# Processing Record 44 of Set 7 | kyren
# Processing Record 45 of Set 7 | korla
# Processing Record 46 of Set 7 | padang
# Processing Record 47 of Set 7 | mariinsk
# Processing Record 48 of Set 7 | ouallam
# Processing Record 49 of Set 7 | luderitz
# Processing Record 0 of Set 8 | inari
# Processing Record 1 of Set 8 | udachny
# Processing Record 2 of Set 8 | acacias
# Processing Record 3 of Set 8 | valparaiso
# Processing Record 4 of Set 8 | cockburn town
# Processing Record 5 of Set 8 | dapa
# Processing Record 6 of Set 8 | kannangad
# Processing Record 7 of Set 8 | hinton
# Processing Record 8 of Set 8 | ivdel'
# Processing Record 9 of Set 8 | broome
# Processing Record 10 of Set 8 | tralee
# Processing Record 11 of Set 8 | prince rupert
# Processing Record 12 of Set 8 | nemuro
# Processing Record 13 of Set 8 | okhotsk
# Processing Record 14 of Set 8 | magadan
# Processing Record 15 of Set 8 | bathsheba
# Processing Record 16 of Set 8 | vadso
# Processing Record 17 of Set 8 | cozumel
# Processing Record 18 of Set 8 | pisco
# Processing Record 19 of Set 8 | beledweyne
# Processing Record 20 of Set 8 | sogndal
# Processing Record 21 of Set 8 | visby
# Processing Record 22 of Set 8 | rudbar
# Processing Record 23 of Set 8 | anloga
# Processing Record 24 of Set 8 | antsirabe
# Processing Record 25 of Set 8 | lerwick
# Processing Record 26 of Set 8 | ceerigaabo
# Processing Record 27 of Set 8 | sur
# Processing Record 28 of Set 8 | vila velha
# Processing Record 29 of Set 8 | east ballina
# Processing Record 30 of Set 8 | pampierstad
# Processing Record 31 of Set 8 | kill devil hills
# Processing Record 32 of Set 8 | twon-brass
# Processing Record 33 of Set 8 | jacmel
# Processing Record 34 of Set 8 | kalix
# Processing Record 35 of Set 8 | nar'yan-mar
# Processing Record 36 of Set 8 | china
# Processing Record 37 of Set 8 | tokonou
# Processing Record 38 of Set 8 | la ronge
# Processing Record 39 of Set 8 | fauske
# Processing Record 40 of Set 8 | mossel bay
# Processing Record 41 of Set 8 | usinsk
# Processing Record 42 of Set 8 | meadow lake
# Processing Record 43 of Set 8 | ponta delgada
# Processing Record 44 of Set 8 | waycross
# Processing Record 45 of Set 8 | vilhena
# Processing Record 46 of Set 8 | chinde
# Processing Record 47 of Set 8 | porbandar
# Processing Record 48 of Set 8 | santiago de cuba
# Processing Record 49 of Set 8 | khanty-mansiysk
# Processing Record 0 of Set 9 | balabac
# Processing Record 1 of Set 9 | yurga
# Processing Record 2 of Set 9 | kenora
# Processing Record 3 of Set 9 | veraval
# Processing Record 4 of Set 9 | arkhipo-osipovka
# Processing Record 5 of Set 9 | katsuura
# Processing Record 6 of Set 9 | pitkyaranta
# Processing Record 7 of Set 9 | la plata
# Processing Record 8 of Set 9 | kerema
# Processing Record 9 of Set 9 | bandarbeyla
# Processing Record 10 of Set 9 | smithers
# Processing Record 11 of Set 9 | waingapu
# Processing Record 12 of Set 9 | qamdo
# Processing Record 13 of Set 9 | xuddur
# Processing Record 14 of Set 9 | de aar
# Processing Record 15 of Set 9 | maebaru-chuo
# Processing Record 16 of Set 9 | vilyuchinsk
# Processing Record 17 of Set 9 | east toowoomba
# Processing Record 18 of Set 9 | nyurba
# Processing Record 19 of Set 9 | ruokolahti
# Processing Record 20 of Set 9 | guigang
# Processing Record 21 of Set 9 | yayci
# City not found. Skipping...
# Processing Record 22 of Set 9 | vershino-darasunskiy
# Processing Record 23 of Set 9 | dien bien phu
# Processing Record 24 of Set 9 | sabang
# Processing Record 25 of Set 9 | cromer
# Processing Record 26 of Set 9 | berezovyy
# Processing Record 27 of Set 9 | lodwar
# Processing Record 28 of Set 9 | troitsko-pechorsk
# Processing Record 29 of Set 9 | rock springs
# Processing Record 30 of Set 9 | toga village
# City not found. Skipping...
# Processing Record 31 of Set 9 | san antonio del estrecho
# City not found. Skipping...
# Processing Record 32 of Set 9 | mahanoro
# Processing Record 33 of Set 9 | kenai
# Processing Record 34 of Set 9 | kimbe
# Processing Record 35 of Set 9 | khovd
# Processing Record 36 of Set 9 | baiyin
# Processing Record 37 of Set 9 | tucuma
# Processing Record 38 of Set 9 | horta
# Processing Record 39 of Set 9 | auki
# Processing Record 40 of Set 9 | ambikapur
# Processing Record 41 of Set 9 | ghanzi
# Processing Record 42 of Set 9 | vallenar
# Processing Record 43 of Set 9 | zambezi
# Processing Record 44 of Set 9 | pasuquin
# Processing Record 45 of Set 9 | callao
# Processing Record 46 of Set 9 | samtse
# Processing Record 47 of Set 9 | ngou
# Processing Record 48 of Set 9 | shalkar
# Processing Record 49 of Set 9 | goure
# Processing Record 0 of Set 10 | new bern
# Processing Record 1 of Set 10 | humaita
# Processing Record 2 of Set 10 | page
# Processing Record 3 of Set 10 | joaquin v. gonzalez
# Processing Record 4 of Set 10 | yilan
# Processing Record 5 of Set 10 | parambu
# Processing Record 6 of Set 10 | ketchikan
# Processing Record 7 of Set 10 | tubarjal
# Processing Record 8 of Set 10 | zakamensk
# Processing Record 9 of Set 10 | weligama
# Processing Record 10 of Set 10 | yokadouma
# Processing Record 11 of Set 10 | galliano
# Processing Record 12 of Set 10 | maturin
# Processing Record 13 of Set 10 | puerto san carlos
# City not found. Skipping...
# Processing Record 14 of Set 10 | noshiro
# Processing Record 15 of Set 10 | menaka
# Processing Record 16 of Set 10 | karratha
# Processing Record 17 of Set 10 | 'ohonua
# City not found. Skipping...
# Processing Record 18 of Set 10 | lazaro cardenas
# Processing Record 19 of Set 10 | banda aceh
# Processing Record 20 of Set 10 | monrovia
# Processing Record 21 of Set 10 | outjo
# Processing Record 22 of Set 10 | gagarin
# Processing Record 23 of Set 10 | puerto armuelles
# Processing Record 24 of Set 10 | bengkulu
# Processing Record 25 of Set 10 | la foa
# Processing Record 26 of Set 10 | hun
# Processing Record 27 of Set 10 | codrington
# Processing Record 28 of Set 10 | dwarka
# Processing Record 29 of Set 10 | labrador city
# Processing Record 30 of Set 10 | daru
# Processing Record 31 of Set 10 | farasan
# Processing Record 32 of Set 10 | puerto baquerizo moreno
# Processing Record 33 of Set 10 | lata
# Processing Record 34 of Set 10 | i-n-salah
# Processing Record 35 of Set 10 | kargasok
# Processing Record 36 of Set 10 | priozersk
# Processing Record 37 of Set 10 | val-d'or
# Processing Record 38 of Set 10 | kasama
# Processing Record 39 of Set 10 | dampit
# Processing Record 40 of Set 10 | eyl
# Processing Record 41 of Set 10 | carutapera
# Processing Record 42 of Set 10 | haiku-pauwela
# Processing Record 43 of Set 10 | island harbour
# Processing Record 44 of Set 10 | puri
# Processing Record 45 of Set 10 | spring creek
# Processing Record 46 of Set 10 | masterton
# Processing Record 47 of Set 10 | bikenibeu village
# Processing Record 48 of Set 10 | manado
# Processing Record 49 of Set 10 | engenheiro beltrao
# Processing Record 0 of Set 11 | cidreira
# Processing Record 1 of Set 11 | nadi
# Processing Record 2 of Set 11 | radhanpur
# Processing Record 3 of Set 11 | tyukhtet
# Processing Record 4 of Set 11 | graaff-reinet
# Processing Record 5 of Set 11 | paso de los toros
# Processing Record 6 of Set 11 | sao jose da coroa grande
# Processing Record 7 of Set 11 | novyy urengoy
# Processing Record 8 of Set 11 | monte cristo
# Processing Record 9 of Set 11 | sao gabriel da cachoeira
# Processing Record 10 of Set 11 | al burayqah
# Processing Record 11 of Set 11 | st. john's
# Processing Record 12 of Set 11 | manaure
# Processing Record 13 of Set 11 | balkanabat
# Processing Record 14 of Set 11 | port augusta
# Processing Record 15 of Set 11 | yagry
# City not found. Skipping...
# Processing Record 16 of Set 11 | severnoye
# Processing Record 17 of Set 11 | volkhov
# Processing Record 18 of Set 11 | happy valley-goose bay
# Processing Record 19 of Set 11 | sinop
# Processing Record 20 of Set 11 | wynne
# Processing Record 21 of Set 11 | ghat
# Processing Record 22 of Set 11 | alo
# Processing Record 23 of Set 11 | kourou
# Processing Record 24 of Set 11 | morris
# Processing Record 25 of Set 11 | narvik
# Processing Record 26 of Set 11 | rurrenabaque
# Processing Record 27 of Set 11 | kuvandyk
# Processing Record 28 of Set 11 | rouyn-noranda
# Processing Record 29 of Set 11 | nikolayevsk-on-amure
# Processing Record 30 of Set 11 | kapuskasing
# Processing Record 31 of Set 11 | usakos
# Processing Record 32 of Set 11 | st. paul
# Processing Record 33 of Set 11 | suai
# City not found. Skipping...
# Processing Record 34 of Set 11 | liwale
# Processing Record 35 of Set 11 | iranshahr
# Processing Record 36 of Set 11 | ukiah
# Processing Record 37 of Set 11 | puerto montt
# Processing Record 38 of Set 11 | vi thanh
# Processing Record 39 of Set 11 | port glaud
# City not found. Skipping...
# Processing Record 40 of Set 11 | port hueneme
# Processing Record 41 of Set 11 | portel
# Processing Record 42 of Set 11 | antsohihy
# Processing Record 43 of Set 11 | weno
# Processing Record 44 of Set 11 | gangapur
# Processing Record 45 of Set 11 | undurkhaan
# Processing Record 46 of Set 11 | shirvan
# Processing Record 47 of Set 11 | talara
# Processing Record 48 of Set 11 | wanning
# Processing Record 49 of Set 11 | san antonio de pale
# Processing Record 0 of Set 12 | annaba
# Processing Record 1 of Set 12 | tanaina
# Processing Record 2 of Set 12 | caleta de carquin
# Processing Record 3 of Set 12 | thunder bay
# Processing Record 4 of Set 12 | sheopur
# Processing Record 5 of Set 12 | el granada
# Processing Record 6 of Set 12 | tumayr
# Processing Record 7 of Set 12 | kavieng
# Processing Record 8 of Set 12 | vohibinany
# Processing Record 9 of Set 12 | talakan
# Processing Record 10 of Set 12 | malango
# Processing Record 11 of Set 12 | likisa
# Processing Record 12 of Set 12 | novo aripuana
# Processing Record 13 of Set 12 | guane
# Processing Record 14 of Set 12 | namdrik
# Processing Record 15 of Set 12 | tadine
# Processing Record 16 of Set 12 | beau vallon
# Processing Record 17 of Set 12 | chibougamau
# Processing Record 18 of Set 12 | fonadhoo
# City not found. Skipping...
# Processing Record 19 of Set 12 | san jose village
# City not found. Skipping...
# Processing Record 20 of Set 12 | fort bragg
# Processing Record 21 of Set 12 | labytnangi
# Processing Record 22 of Set 12 | agadez
# Processing Record 23 of Set 12 | brownfield
# Processing Record 24 of Set 12 | alvaraes
# Processing Record 25 of Set 12 | kirakira
# Processing Record 26 of Set 12 | juegang
# Processing Record 27 of Set 12 | yerofey pavlovich
# Processing Record 28 of Set 12 | anatuya
# Processing Record 29 of Set 12 | diapaga
# Processing Record 30 of Set 12 | florida
# Processing Record 31 of Set 12 | butembo
# Processing Record 32 of Set 12 | yashan
# Processing Record 33 of Set 12 | peterhead
# Processing Record 34 of Set 12 | tamandare
# Processing Record 35 of Set 12 | mpongwe
# Processing Record 36 of Set 12 | genhe
# Processing Record 37 of Set 12 | nyandoma
# Processing Record 38 of Set 12 | rosarito
# Processing Record 39 of Set 12 | guiuan
# Processing Record 40 of Set 12 | barclayville
# Processing Record 41 of Set 12 | ringkobing
# Processing Record 42 of Set 12 | kozhevnikovo
# Processing Record 43 of Set 12 | tut
# Processing Record 44 of Set 12 | kerikeri
# Processing Record 45 of Set 12 | kisangani
# Processing Record 46 of Set 12 | dabeiba
# Processing Record 47 of Set 12 | soma
# Processing Record 48 of Set 12 | dayton
# Processing Record 49 of Set 12 | hirekerur
# Processing Record 0 of Set 13 | quellon
# Processing Record 1 of Set 13 | eureka
# Processing Record 2 of Set 13 | huarmey
# Processing Record 3 of Set 13 | m'sila
# Processing Record 4 of Set 13 | mongo
# Processing Record 5 of Set 13 | qiongshan
# -----------------------------
# Data Retrieval Complete
# -----------------------------

# %%
# Convert the cities weather data into a Pandas DataFrame
city_data_df = pd.DataFrame(city_data)

# Show Record Count
city_data_df.count()
# Out:
# City          580
# Lat           580
# Lng           580
# Max Temp      580
# Humidity      580
# Cloudiness    580
# Wind Speed    580
# Country       580
# Date          580
# dtype: int64

# %%
# Display sample data
city_data_df.head()
# Out:
#          City      Lat       Lng  Max Temp  Humidity  Cloudiness  Wind Speed  \
# 0  constantia  44.1833   28.6500     29.08        52           2        8.01
# 1      kodiak  57.7900 -152.4072     26.11        93           0        3.44
# 2    waitangi -43.9535 -176.5597     55.81        96          67        5.01
# 3    khandyga  62.6667  135.6000    -23.33        99          24        2.53
# 4      saipan  15.1355  145.7010     83.10        86          40       18.41
#
#   Country        Date
# 0      RO  1732555447
# 1      US  1732555394
# 2      NZ  1732555353
# 3      RU  1732555538
# 4      MP  1732555539

# %%
# Export the City_Data into a csv
city_data_df.to_csv("output_data/cities.csv", index_label="City_ID")

# %%
# Read saved data
city_data_df = pd.read_csv("output_data/cities.csv", index_col="City_ID")

# Display sample data
city_data_df.head()
# Out:
#                City      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# City_ID
# 0        constantia  44.1833   28.6500     29.08        52           2
# 1            kodiak  57.7900 -152.4072     26.11        93           0
# 2          waitangi -43.9535 -176.5597     55.81        96          67
# 3          khandyga  62.6667  135.6000    -23.33        99          24
# 4            saipan  15.1355  145.7010     83.10        86          40
#
#          Wind Speed Country        Date
# City_ID
# 0              8.01      RO  1732555447
# 1              3.44      US  1732555394
# 2              5.01      NZ  1732555353
# 3              2.53      RU  1732555538
# 4             18.41      MP  1732555539

# %% [markdown]
# ### Create the Scatter Plots Requested
#
# #### Latitude Vs. Temperature

# %%
# Build scatter plot for latitude vs. temperature
plt.scatter(
    city_data_df["Lat"],
    city_data_df["Max Temp"],
    color="gold",
    edgecolor="black",
    linewidths=1,
    marker="o",
    label="Cities",
    s=50
)

# Incorporate the other graph properties
plt.title("City Latitude vs. Temperature (%s)" % time.strftime("%m-%d-%Y"))
plt.xlabel("Latitude")
plt.ylabel("Max Temperature (F)")
plt.grid(True)

# Save the figure
plt.savefig("output_data/Fig1.png")

# Show plot
plt.show()

# %% [markdown]
# #### Latitude Vs. Humidity

# %%
# Build the scatter plots for latitude vs. humidity
plt.scatter(
    city_data_df["Lat"],
    city_data_df["Humidity"],
    color="pink",
    edgecolor="black",
    linewidths=1,
    marker="o",
    label="Cities",
    s=50
)

# Incorporate the other graph properties
plt.title("City Latitude vs. Humidity (%s)" % time.strftime("%m-%d-%Y"))
plt.xlabel("Latitude")
plt.ylabel("Humidity")
plt.grid(True)

# Save the figure
plt.savefig("output_data/Fig2.png")

# Show plot
plt.show()

# %% [markdown]
# #### Latitude Vs. Cloudiness

# %%
# Build the scatter plots for latitude vs. cloudiness
plt.scatter(
    city_data_df["Lat"],
    city_data_df["Cloudiness"],
    color="gray",
    edgecolor="black",
    linewidths=1,
    marker="o",
    label="Cities",
    s=50
)

# Incorporate the other graph properties
plt.title("City Latitude vs. Cloudiness (%s)" % time.strftime("%m-%d-%Y"))
plt.xlabel("Latitude")
plt.ylabel("Cloudiness")
plt.grid(True)

# Save the figure
plt.savefig("output_data/Fig3.png")

# Show plot
plt.show()

# %% [markdown]
# #### Latitude vs. Wind Speed Plot

# %%
# Build the scatter plots for latitude vs. wind speed
plt.scatter(
    city_data_df["Lat"],
    city_data_df["Wind Speed"],
    color="orange",
    edgecolor="black",
    linewidths=1,
    marker="o",
    label="Cities",
    s=50
)

# Incorporate the other graph properties
plt.title("City Latitude vs. Wind Speed (%s)" % time.strftime("%m-%d-%Y"))
plt.xlabel("Latitude")
plt.ylabel("Wind Speed")
plt.grid(True)

# Save the figure
plt.savefig("output_data/Fig4.png")

# Show plot
plt.show()

# %% [markdown]
# ---
#
# ## Requirement 2: Compute Linear Regression for Each Relationship

# %%
# Define a function to create Linear Regression plots
def plot_linear_regression(x_values, y_values, title, text_coordinates, color):

    # Compute linear regression
    (slope, intercept, rvalue, pvalue, stderr) = linregress(x_values, y_values)
    regress_values = x_values * slope + intercept
    line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))

    # Plot
    plt.scatter(x_values, y_values, color=color, edgecolor="black", s=50)
    plt.plot(x_values, regress_values,"r-")
    plt.annotate(line_eq,text_coordinates,fontsize=15,color="red")
    plt.xlabel("Latitude")
    plt.ylabel(title)
    print(f"The r-value is: {rvalue**2}")
    plt.show()

# %%
# Create a DataFrame with the Northern Hemisphere data (Latitude >= 0)
northern_hemi_df = city_data_df.loc[(city_data_df["Lat"] >= 0)]

# Display sample data
northern_hemi_df.head()
# Out:
#                 City      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# City_ID
# 0         constantia  44.1833   28.6500     29.08        52           2
# 1             kodiak  57.7900 -152.4072     26.11        93           0
# 3           khandyga  62.6667  135.6000    -23.33        99          24
# 4             saipan  15.1355  145.7010     83.10        86          40
# 7        yellowknife  62.4560 -114.3525     16.32        92         100
#
#          Wind Speed Country        Date
# City_ID
# 0              8.01      RO  1732555447
# 1              3.44      US  1732555394
# 3              2.53      RU  1732555538
# 4             18.41      MP  1732555539
# 7             13.80      CA  1732555542

# %%
# Create a DataFrame with the Southern Hemisphere data (Latitude < 0)
southern_hemi_df = city_data_df.loc[(city_data_df["Lat"] < 0)]

# Display sample data
southern_hemi_df.head()
# Out:
#                         City      Lat       Lng  Max Temp  Humidity  \
# City_ID
# 2                   waitangi -43.9535 -176.5597     55.81        96
# 5               punta arenas -53.1500  -70.9167     51.91        54
# 6        veinticinco de mayo -35.4323  -60.1727     79.99        69
# 8          port-aux-francais -49.3500   70.2167     40.73        93
# 9           flying fish cove -10.4217  105.6791     82.42        77
#
#          Cloudiness  Wind Speed Country        Date
# City_ID
# 2                67        5.01      NZ  1732555353
# 5                 0       10.36      CL  1732555287
# 6                48        8.99      AR  1732555541
# 8                84       38.30      TF  1732555497
# 9                92        4.41      CX  1732555545

# %% [markdown]
# ###  Temperature vs. Latitude Linear Regression Plot

# %%
# Linear regression on Northern Hemisphere
x_values = northern_hemi_df["Lat"]
y_values = northern_hemi_df["Max Temp"]
plot_linear_regression(x_values, y_values, "Max Temp",(6,-10), "gold")
# Out:
# The r-value is: 0.7431559900324602

# %%
# Linear regression on Southern Hemisphere
x_values = southern_hemi_df["Lat"]
y_values = southern_hemi_df["Max Temp"]
plot_linear_regression(x_values, y_values, "Max Temp",(-55,90), "gold")
# Out:
# The r-value is: 0.5008636334941481

# %% [markdown]
# **Discussion about the linear relationship:** The high r value ~0.7 indicates a strong positive correlation between latitude and max temperature in the northern hemisphere. R value ~ 0.5 indiciate there is a moderate positive correlation in the southern hemisphere due to seasonal changes.

# %% [markdown]
# ### Humidity vs. Latitude Linear Regression Plot

# %%
# Northern Hemisphere
x_values = northern_hemi_df["Lat"]
y_values = northern_hemi_df["Humidity"]
plot_linear_regression(x_values, y_values, "Humidity",(55,18), "pink")
# Out:
# The r-value is: 0.17165006918741388

# %%
# Southern Hemisphere
x_values = southern_hemi_df["Lat"]
y_values = southern_hemi_df["Humidity"]
plot_linear_regression(x_values, y_values, "Humidity",(-20,35), "pink")
# Out:
# The r-value is: 0.0025648960158455524

# %% [markdown]
# **Discussion about the linear relationship:** The low r values indicate a weak to no relationship between humidity and latitude.

# %% [markdown]
# ### Cloudiness vs. Latitude Linear Regression Plot

# %%
# Northern Hemisphere
x_values = northern_hemi_df["Lat"]
y_values = northern_hemi_df["Cloudiness"]
plot_linear_regression(x_values, y_values, "Cloudiness",(50,50), "gray")
# Out:
# The r-value is: 0.064653744758002

# %%
# Southern Hemisphere
x_values = southern_hemi_df["Lat"]
y_values = southern_hemi_df["Cloudiness"]
plot_linear_regression(x_values, y_values, "Cloudiness",(-55,20), "gray")
# Out:
# The r-value is: 0.022832805960497155

# %% [markdown]
# **Discussion about the linear relationship:** The low r values indicate a weak to no relationship between cloudiness and latitude.

# %% [markdown]
# ### Wind Speed vs. Latitude Linear Regression Plot

# %%
# Northern Hemisphere
x_values = northern_hemi_df["Lat"]
y_values = northern_hemi_df["Wind Speed"]
plot_linear_regression(x_values, y_values, "Wind Speed",(50,35), "orange")
# Out:
# The r-value is: 0.051344529027397424

# %%
# Southern Hemisphere
x_values = southern_hemi_df["Lat"]
y_values = southern_hemi_df["Wind Speed"]
plot_linear_regression(x_values, y_values, "Wind Speed",(-30,30), "orange")
# Out:
# The r-value is: 0.041724328581372955

# %% [markdown]
# **Discussion about the linear relationship:** The low r values indicate a weak to no relationship between wind speed and latitude.
